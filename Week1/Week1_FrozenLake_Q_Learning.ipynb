# %% [markdown]
# # Week 1: Q-Learning on FrozenLake

# %% [markdown]
# Welcome to Week 1! This week we’ll get hands-on with **Q-learning** using OpenAI Gym’s **FrozenLake-v1** environment. Your goal is to train a tabular Q-learning agent to navigate a slippery frozen lake without falling into holes.

# %% [markdown]
# Read about the FrozenLake environment from the openAI gymnasium website and try to solve this assignment

# %% [markdown]
# ## Goals

# %% [markdown]
# - Understand and implement Q-learning with a Q-table.
# - Use an ε-greedy exploration strategy.
# - Visualize training progress with reward curves.
# - Evaluate the learned policy.

# %% [markdown]
# ## Environment Setup

# %%
# !pip install gym==0.26.2 matplotlib numpy
# Out:
# Requirement already satisfied: gym==0.26.2 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (0.26.2)
# Requirement already satisfied: matplotlib in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (3.10.3)
# Requirement already satisfied: numpy in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (2.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from gym==0.26.2) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from gym==0.26.2) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sparshgupta/Documents/Battle-Of-The-Bots/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from gym.envs.toy_text.frozen_lake import FrozenLakeEnv

env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="ansi")
state_space_size = env.observation_space.n
action_space_size = env.action_space.n
Q = np.zeros((state_space_size, action_space_size))

# %% [markdown]
# ## Training Loop
# Complete the training loop

# %%
def train_agent(episodes=2000, alpha=0.8, gamma=0.95, epsilon=1.0, decay=0.995):
    rewards = []
    for ep in range(episodes):
        state = env.reset()[0]
        done = False
        total_reward = 0
        while not done:
            #TODO select action
            if np.random.rand() <= epsilon:
                action = env.action_space.sample()
            else:
                action = np.argmax(Q[state, :])

            next_state, reward, done, _, _ = env.step(action) #uncomment this after adding algo to choose action
            
            #TODO Update The Q values
            Q[state, action] = Q[state, action] + alpha*(reward + gamma*np.max(Q[next_state, action]) - Q[state, action])
    
            state = next_state
            total_reward += reward

        #TODO maybe try decaying epsilon between episodes
        epsilon *= decay
        if epsilon < 0.01 :
            epsilon = 0.01
        alpha = alpha/(1 + decay*ep)

        rewards.append(total_reward)
    return rewards

# %% [markdown]
# ## Plotting Results

# %%
rewards = train_agent()
plt.plot(np.convolve(rewards, np.ones(100)/100, mode='valid'))
plt.title("100-Episode Moving Average of Rewards")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.show()

# %% [markdown]
# ## Test the Learned Policy

# %%
def test_agent(Q, episodes=5):
    for ep in range(episodes):
        state = env.reset()[0]
        done = False
        print(f"Episode {ep + 1}")
        while not done:
            action = np.argmax(Q[state])
            next_state, reward, done, truncated, _ = env.step(action)
            env.render()
            state = next_state
            if truncated:
                done = True

# %%
test_agent(Q)
# Out:
# Episode 1
# Episode 2
# Episode 3
# Episode 4
# Episode 5

# %% [markdown]
# ## Challenges

# %% [markdown]
# 1. Set `is_slippery=False` and compare performance.
# 2. Change the reward for falling into holes.
# 3. Add a decaying learning rate `α = α0 / (1 + decay * t)`.
# 4. Visualize the Q-table as a heatmap (optional).
# 5. Maybe try to think about how to generalize this to solve a random lake without pretraining on the specific environment(Post your ideas on the whatsapp group and we will host a competition if people are interested)

# %% [markdown]
# ## TLDR

# %% [markdown]
# Learn how to implement tabular Q-learning to solve a simple environment. Use exploration, value updates, and reward tracking to build intuition before moving to deep RL.
